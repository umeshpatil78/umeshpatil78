# %% [markdown]
# Write a program to demonstrate different number data types in Python.![Untitled111.png](data:image/png;base64,...)

# %%
x = 20     #int
print(x)
print(type(x))
x = 20.5 #float
print(x)
print(type(x))
x = 1j        #complex
print(x)
print(type(x))
# Out:
# 20
# <class 'int'>
# 20.5
# <class 'float'>
# 1j
# <class 'complex'>

# %%
#String
x = "rcpit.ac.in"   
print(x)
print(type(x))
# Out:
# rcpit.ac.in
# <class 'str'>

# %%
x = ["Shirpur", "RCPIT", "Electrical"]       #list
print(x)
print(type(x))
# Out:
# ['Shirpur', 'RCPIT', 'Electrical']
# <class 'list'>

# %%
x = ("Python", "from", "rcpit.ac.in")       #tuple
print(x)
print(type(x))
# Out:
# ('Python', 'from', 'rcpit.ac.in')
# <class 'tuple'>

# %%
x = {"name" : "anu", "age" : 36}  #dict
print(x)
print(type(x))
# Out:
# {'name': 'anu', 'age': 36}
# <class 'dict'>

# %%
x = True  #bool
print(x)
print(type(x))
x = b"Hello"  #bytes
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>
# b'Hello'
# <class 'bytes'>

# %%
x = {"dl", "python", "ml"}   #set
print(x)
print(type(x))
x = frozenset({"opencv", "pandas", "numpy"}) #frozenset
print(x)
print(type(x))
# Out:
# {'dl', 'python', 'ml'}
# <class 'set'>
# frozenset({'pandas', 'numpy', 'opencv'})
# <class 'frozenset'>
